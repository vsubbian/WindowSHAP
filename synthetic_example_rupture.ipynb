# %% [markdown]
# # Synthetic data

# %%
import timeit
import warnings

import numpy as np
import shap
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
from utils import heat_map
import ruptures as rpt

from window_shap import SlidingWindowSHAP, StationaryWindowSHAP, DynamicWindowSHAP, RupturesDynamicWindowSHAP

warnings.filterwarnings('ignore')

# %matplotlib inline
shap.initjs()
# Out:
# 2024-01-18 21:49:30.948187: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# This function generates a synthetic time series in which each feature sequence is generated using the sin() or cos() function. However, an anomaly interval is inserted at random into one of the feature sequences. If the feature with the anomaly is the first feature, the sample label is 1; otherwise, it is 0.

# %%
def synthetic_data(n_samples=100, n_steps=10, n_features=4, seed=False):

    # Creating input data
    lam = 0.2
    anomaly_lam = 10
    rng = np.random.default_rng(12345)

    eps = rng.normal
    x = np.zeros((n_samples, n_steps, n_features))
    labels = np.zeros(n_samples)
    for i in range(n_samples):
        t0 = rng.integers(1, 5, size=n_features)
        w = rng.integers(1, 5, size=n_features)
        t = np.arange(n_steps)
        for j in range(n_features):
            if j % 2 == 0:
                x[i, :, j] = np.sin((t - t0[j]) / w[j])
            else:
                x[i, :, j] = np.cos((t - t0[j]) / w[j])
            x[i, :, j] = x[i, :, j] + lam * eps(size=n_steps)

        # adding anomaly
        #         anom_dur = np.random.randint(n_steps/10, n_steps/2)
        anom_dur = 20
        anom_start = rng.integers(0, n_steps - anom_dur)
        anom_end = anom_start + anom_dur

        anom_j = rng.integers(0, n_features)
        x[i, anom_start:anom_end, anom_j] += anomaly_lam * eps(size=anom_dur)

        # Creating the label
        labels[i] = 1 if anom_j == 0 else 0
    return x, labels

# %% [markdown]
# Data seperation to test and train

# %%
x, label = synthetic_data(n_samples=10000, n_steps=120, n_features=4)
train_x, test_x, train_y, test_y = train_test_split(x, label, test_size=0.3, random_state=0,
                                                    stratify=label)
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=0,
                                                  stratify=train_y)

# %% [markdown]
# # Prediction Model

# %%
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers

num_hidden = [70, 20]
num_neurons = 200
es_patience = 20
epochs = 20
num_output = 1
batch_size = 32
drop_rate = 0.3
reg_rate = 0.004

K.clear_session()
model = Sequential()
input_shape = (x.shape[1], x.shape[2])
model.add(GRU(units=num_neurons, activation='relu', input_shape=input_shape,
              recurrent_dropout=0.1, dropout=0.1))
for i in num_hidden:
    model.add(Dropout(drop_rate))
    model.add(Dense(units=i, activation='relu', kernel_regularizer=regularizers.l2(reg_rate)))
model.add(Dense(units=num_output, activation='sigmoid'))

# Creating and compiling model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=es_patience)

# Class weights
class_weights = {0: len(train_y) / (train_y == 0).sum(),
                 1: len(train_y) / (train_y == 1).sum()}

model.compile(optimizer=SGD(learning_rate=0.01, clipvalue=0.5), loss='binary_crossentropy',
              metrics=['accuracy'])
# model.build(input_shape)
model.summary()
train_history = model.fit(train_x, train_y, batch_size=batch_size,
                          epochs=epochs, verbose=2,
                          validation_data=(val_x, val_y),
                          class_weight=class_weights,
                          callbacks=[es])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 200)               123600
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 70)                14070
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 20)                1420
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 139111 (543.40 KB)
# Trainable params: 139111 (543.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 175/175 - 22s - loss: 1.9181 - accuracy: 0.3839 - val_loss: 1.2243 - val_accuracy: 0.2886 - 22s/epoch - 123ms/step
# Epoch 2/20
# 175/175 - 15s - loss: 1.9031 - accuracy: 0.4654 - val_loss: 1.2040 - val_accuracy: 0.4664 - 15s/epoch - 88ms/step
# Epoch 3/20
# 175/175 - 15s - loss: 1.8869 - accuracy: 0.4868 - val_loss: 1.1878 - val_accuracy: 0.5221 - 15s/epoch - 88ms/step
# Epoch 4/20
# 175/175 - 20s - loss: 1.8732 - accuracy: 0.5504 - val_loss: 1.1756 - val_accuracy: 0.4743 - 20s/epoch - 112ms/step
# Epoch 5/20
# 175/175 - 18s - loss: 1.8571 - accuracy: 0.5280 - val_loss: 1.1634 - val_accuracy: 0.4693 - 18s/epoch - 101ms/step
# Epoch 6/20
# 175/175 - 17s - loss: 1.8442 - accuracy: 0.5502 - val_loss: 1.1491 - val_accuracy: 0.5100 - 17s/epoch - 97ms/step
# Epoch 7/20
# 175/175 - 16s - loss: 1.8290 - accuracy: 0.5150 - val_loss: 1.1306 - val_accuracy: 0.5821 - 16s/epoch - 93ms/step
# Epoch 8/20
# 175/175 - 17s - loss: 1.8158 - accuracy: 0.5554 - val_loss: 1.1236 - val_accuracy: 0.5221 - 17s/epoch - 99ms/step
# Epoch 9/20
# 175/175 - 17s - loss: 1.8033 - accuracy: 0.5564 - val_loss: 1.1086 - val_accuracy: 0.5457 - 17s/epoch - 96ms/step
# Epoch 10/20
# 175/175 - 16s - loss: 1.7871 - accuracy: 0.5468 - val_loss: 1.0936 - val_accuracy: 0.5814 - 16s/epoch - 92ms/step
# Epoch 11/20
# 175/175 - 17s - loss: 1.7753 - accuracy: 0.5663 - val_loss: 1.0809 - val_accuracy: 0.5821 - 17s/epoch - 98ms/step
# Epoch 12/20
# 175/175 - 17s - loss: 1.7612 - accuracy: 0.5736 - val_loss: 1.0707 - val_accuracy: 0.5686 - 17s/epoch - 98ms/step
# Epoch 13/20
# 175/175 - 17s - loss: 1.7431 - accuracy: 0.5920 - val_loss: 1.0594 - val_accuracy: 0.5636 - 17s/epoch - 97ms/step
# Epoch 14/20
# 175/175 - 17s - loss: 1.6824 - accuracy: 0.6143 - val_loss: 0.9040 - val_accuracy: 0.8279 - 17s/epoch - 95ms/step
# Epoch 15/20
# 175/175 - 17s - loss: 0.8059 - accuracy: 0.9795 - val_loss: 0.5031 - val_accuracy: 0.9993 - 17s/epoch - 99ms/step
# Epoch 16/20
# 175/175 - 17s - loss: 0.4805 - accuracy: 0.9991 - val_loss: 0.3966 - val_accuracy: 1.0000 - 17s/epoch - 98ms/step
# Epoch 17/20
# 175/175 - 17s - loss: 0.3939 - accuracy: 0.9998 - val_loss: 0.3620 - val_accuracy: 1.0000 - 17s/epoch - 98ms/step
# Epoch 18/20
# 175/175 - 21s - loss: 0.3627 - accuracy: 0.9998 - val_loss: 0.3453 - val_accuracy: 1.0000 - 21s/epoch - 119ms/step
# Epoch 19/20
# 175/175 - 17s - loss: 0.3437 - accuracy: 1.0000 - val_loss: 0.3323 - val_accuracy: 1.0000 - 17s/epoch - 99ms/step
# Epoch 20/20
# 175/175 - 17s - loss: 0.3333 - accuracy: 0.9998 - val_loss: 0.3222 - val_accuracy: 1.0000 - 17s/epoch - 96ms/step

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

print(roc_auc_score(test_y, model.predict(test_x)))
print(accuracy_score(test_y, np.round(model.predict(test_x))))
# Out:
# 94/94 [==============================] - 3s 30ms/step
# 1.0
# 94/94 [==============================] - 3s 28ms/step
# 1.0

# %%
test_y[20:30]
# Out:
# array([0., 0., 1., 0., 0., 0., 1., 0., 1., 1.])

# %% [markdown]
# ## SHAP interpretation

# %%
num_background = 50
num_test = 28
background_data, test_data = train_x[:num_background], test_x[num_test:num_test + 2]

# %% [markdown]
# ## 1- Stationary WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_1 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    gtw = StationaryWindowSHAP(model, window_len, B_ts=background_data, test_ts=test_data[i:i + 1], model_type='lstm')
    ts_phi_1[i, :, :] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 3275/3275 [==============================] - 79s 24ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 3275/3275 [==============================] - 78s 24ms/step
# Total time: 452.321198083

# %% [markdown]
# ## 2- Sliding WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_2 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    stride = 10
    gtw = SlidingWindowSHAP(model, stride, window_len, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_2[i, :, :] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 63/63 [==============================] - 2s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 63/63 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 72ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 135ms/step
# 63/63 [==============================] - 3s 44ms/step
# 2/2 [==============================] - 0s 42ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 63/63 [==============================] - 3s 51ms/step
# 2/2 [==============================] - 0s 37ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 44ms/step
# 63/63 [==============================] - 4s 59ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 63/63 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 63/63 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 63/63 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 42ms/step
# 63/63 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 63/63 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 63/63 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 63/63 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 49ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 63/63 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 63/63 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 63/63 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 63/63 [==============================] - 1s 23ms/step
# Total time: 88.95104380300006

# %% [markdown]
# ## 3- Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_3 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    btw = DynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_3[i, :, :] = btw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 13/13 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 16/16 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 19/19 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 22/22 [==============================] - 1s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 29/29 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 32/32 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 38/38 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 3238/3238 [==============================] - 80s 25ms/step
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 13/13 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 16/16 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 54ms/step
# 19/19 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 22/22 [==============================] - 1s 29ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 25/25 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 32/32 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 35/35 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 45ms/step
# 3197/3197 [==============================] - 78s 25ms/step
# Total time: 261.65569752199997

# %%
var = 0
phi_index = 0

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_1[phi_index, :, var], var_name='Observed', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_2[phi_index, :, var], var_name='Observed', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_3[phi_index, :, var], var_name='Variable', plot_type='bar')

# %% [markdown]
# ## 4 Dynp - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
dynp_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    dynp = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="Dynp", rpt_pen=3, rpt_model='rbf', n_bkps=3)
    dynp_phi[i, :, :] = dynp.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120]]
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 50/50 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 27ms/step
# 54/54 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 44ms/step
# 57/57 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 42ms/step
# 60/60 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 48ms/step
# 66/66 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 3266/3266 [==============================] - 83s 25ms/step
# Split points
# [[80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120]]
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 50/50 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 54/54 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 57/57 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 60/60 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 66/66 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 3266/3266 [==============================] - 80s 24ms/step
# Total time: 277.6858100700001

# %% [markdown]
# ## 4 Pelt - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
pelt_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    pelt = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="Pelt", rpt_pen=3, rpt_model='rbf')
    pelt_phi[i, :, :] = pelt.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[80, 100, 120], [80, 100, 120], [80, 100, 120], [80, 100, 120]]
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 59ms/step
# 38/38 [==============================] - 1s 36ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 41/41 [==============================] - 1s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 44/44 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 56ms/step
# 47/47 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 54/54 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 36ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 3254/3254 [==============================] - 82s 25ms/step
# Split points
# [[80, 100, 120], [80, 100, 120], [80, 100, 120], [80, 100, 120]]
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 38/38 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 41/41 [==============================] - 1s 33ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 44/44 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 26ms/step
# 47/47 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 54/54 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 48ms/step
# 3254/3254 [==============================] - 82s 25ms/step
# Total time: 269.222568313

# %% [markdown]
# ## 4 KernelCPD - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
kernel_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    kernelCPD = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="KernelCPD", rpt_model='rbf', n_bkps=3)
    kernel_phi[i, :, :] = kernelCPD.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[89, 94, 98, 120], [89, 94, 98, 120], [89, 94, 98, 120], [89, 94, 98, 120]]
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 66ms/step
# 50/50 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 43ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 101ms/step
# 54/54 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 57/57 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 63/63 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 3263/3263 [==============================] - 84s 26ms/step
# Split points
# [[89, 94, 98, 120], [89, 94, 98, 120], [89, 94, 98, 120], [89, 94, 98, 120]]
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 45ms/step
# 50/50 [==============================] - 2s 34ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 46ms/step
# 54/54 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 57/57 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 53ms/step
# 60/60 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 66/66 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 3266/3266 [==============================] - 83s 25ms/step
# Total time: 281.94963135700004

# %% [markdown]
# ## 4 Binseg - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
binseg_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    binseg = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="Binseg", rpt_model='rbf', n_bkps=3)
    binseg_phi[i, :, :] = binseg.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120]]
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 50/50 [==============================] - 2s 34ms/step
# 2/2 [==============================] - 0s 40ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 54/54 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 57/57 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 60/60 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 36ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 66/66 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 3266/3266 [==============================] - 81s 25ms/step
# Split points
# [[80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120], [80, 85, 100, 120]]
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 50/50 [==============================] - 2s 32ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 54/54 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 57/57 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 60/60 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 66/66 [==============================] - 2s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 3266/3266 [==============================] - 77s 24ms/step
# Total time: 272.1142610459997

# %% [markdown]
# ## 4 BottomUp - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
bottomup_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    bottomup = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="BottomUp", rpt_model='rbf', n_bkps=3)
    bottomup_phi[i, :, :] = bottomup.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[80, 100, 105, 120], [80, 100, 105, 120], [80, 100, 105, 120], [80, 100, 105, 120]]
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 50/50 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 54/54 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 52ms/step
# 57/57 [==============================] - 2s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 56ms/step
# 60/60 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 66/66 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 36ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 3266/3266 [==============================] - 81s 25ms/step
# Split points
# [[80, 100, 105, 120], [80, 100, 105, 120], [80, 100, 105, 120], [80, 100, 105, 120]]
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 50/50 [==============================] - 1s 29ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 54/54 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 57/57 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 60/60 [==============================] - 2s 36ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 66/66 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 3266/3266 [==============================] - 75s 23ms/step
# Total time: 271.848808748

# %% [markdown]
# ## 4 Window - Ruptures Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
window_phi = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    window = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm', rpt_search="Window", rpt_model='rbf', n_bkps=3)
    window_phi[i, :, :] = window.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[40, 80, 120], [40, 80, 120], [40, 80, 120], [40, 80, 120]]
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 26ms/step
# 38/38 [==============================] - 1s 30ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 29ms/step
# 41/41 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 29ms/step
# 44/44 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 47/47 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 28ms/step
# 50/50 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 3250/3250 [==============================] - 76s 23ms/step
# Split points
# [[40, 80, 120], [40, 80, 120], [40, 80, 120], [40, 80, 120]]
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 27ms/step
# 38/38 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 25ms/step
# 41/41 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 26ms/step
# 44/44 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 25ms/step
# 50/50 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 28ms/step
# 54/54 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 18ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 25ms/step
# 3254/3254 [==============================] - 79s 24ms/step
# Total time: 256.3937527799999

# %%
var = 0
phi_index = 0

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_1[phi_index, :, var], var_name='Observed', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_2[phi_index, :, var], var_name='Observed', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_3[phi_index, :, var], var_name='Variable', plot_type='bar')

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=dynp_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=pelt_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=kernel_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=binseg_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=bottomup_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=window_phi[phi_index, :, var], var_name='Variable', plot_type='bar')
