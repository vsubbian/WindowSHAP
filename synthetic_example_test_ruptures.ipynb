# %% [markdown]
# # Synthetic data

# %%
import timeit
import warnings

import numpy as np
import shap
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
from utils import heat_map
import ruptures as rpt

from window_shap import SlidingWindowSHAP, StationaryWindowSHAP, DynamicWindowSHAP

warnings.filterwarnings('ignore')

# %matplotlib inline
shap.initjs()
# Out:
# 2024-01-18 18:45:04.897912: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# This function generates a synthetic time series in which each feature sequence is generated using the sin() or cos() function. However, an anomaly interval is inserted at random into one of the feature sequences. If the feature with the anomaly is the first feature, the sample label is 1; otherwise, it is 0.

# %%
def synthetic_data(n_samples=100, n_steps=10, n_features=4, seed=False):

    # Creating input data
    lam = 0.2
    anomaly_lam = 10
    rng = np.random.default_rng(12345)

    eps = rng.normal
    x = np.zeros((n_samples, n_steps, n_features))
    labels = np.zeros(n_samples)
    for i in range(n_samples):
        t0 = rng.integers(1, 5, size=n_features)
        w = rng.integers(1, 5, size=n_features)
        t = np.arange(n_steps)
        for j in range(n_features):
            if j % 2 == 0:
                x[i, :, j] = np.sin((t - t0[j]) / w[j])
            else:
                x[i, :, j] = np.cos((t - t0[j]) / w[j])
            x[i, :, j] = x[i, :, j] + lam * eps(size=n_steps)

        # adding anomaly
        #         anom_dur = np.random.randint(n_steps/10, n_steps/2)
        anom_dur = 20
        anom_start = rng.integers(0, n_steps - anom_dur)
        anom_end = anom_start + anom_dur

        anom_j = rng.integers(0, n_features)
        x[i, anom_start:anom_end, anom_j] += anomaly_lam * eps(size=anom_dur)

        # Creating the label
        labels[i] = 1 if anom_j == 0 else 0
    return x, labels

# %%
# def synthetic_data(n_samples=100, n_steps=10, n_features=4):
#     # Creating input data
#     lam = 0.2
#     anomaly_lam = 10
#     eps = np.random.normal
#     x = np.zeros((n_samples, n_steps, n_features))
#     labels = np.zeros(n_samples)
#     for i in range(n_samples):
#         t0 = np.random.randint(1, 5, size=n_features)
#         w = np.random.randint(1, 5, size=n_features)
#         t = np.arange(n_steps)
#         for j in range(n_features):
#             if j % 2 == 0:
#                 x[i, :, j] = np.sin((t - t0[j]) / w[j])
#             else:
#                 x[i, :, j] = np.cos((t - t0[j]) / w[j])
#             x[i, :, j] = x[i, :, j] + lam * eps(size=n_steps)
# 
#         # adding anomaly
#         #         anom_dur = np.random.randint(n_steps/10, n_steps/2)
#         anom_dur = 20
#         anom_start = np.random.randint(0, n_steps - anom_dur)
#         anom_end = anom_start + anom_dur
# 
#         anom_j = np.random.randint(0, n_features)
#         x[i, anom_start:anom_end, anom_j] += anomaly_lam * eps(size=anom_dur)
# 
#         # Creating the label
#         labels[i] = 1 if anom_j == 0 else 0
#     return x, labels

# %% [markdown]
# Data seperation to test and train

# %%
x, label = synthetic_data(n_samples=10000, n_steps=120, n_features=4)

# %%
print(label)
# Out:
# [0. 1. 0. ... 0. 0. 1.]

# %%
train_x, test_x, train_y, test_y = train_test_split(x, label, test_size=0.3, random_state=0,
                                                    stratify=label)
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=0,
                                                  stratify=train_y)

# %% [markdown]
# # Prediction Model

# %%
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers

num_hidden = [70, 20]
num_neurons = 200
es_patience = 20
epochs = 40
num_output = 1
batch_size = 32
drop_rate = 0.3
reg_rate = 0.004

K.clear_session()
model = Sequential()
input_shape = (x.shape[1], x.shape[2])
model.add(GRU(units=num_neurons, activation='relu', input_shape=input_shape,
              recurrent_dropout=0.1, dropout=0.1))
for i in num_hidden:
    model.add(Dropout(drop_rate))
    model.add(Dense(units=i, activation='relu', kernel_regularizer=regularizers.l2(reg_rate)))
model.add(Dense(units=num_output, activation='sigmoid'))

# Creating and compiling model
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=es_patience)

# Class weights
class_weights = {0: len(train_y) / (train_y == 0).sum(),
                 1: len(train_y) / (train_y == 1).sum()}

model.compile(optimizer=SGD(learning_rate=0.01, clipvalue=0.5), loss='binary_crossentropy',
              metrics=['accuracy'])
# model.build(input_shape)
model.summary()
train_history = model.fit(train_x, train_y, batch_size=batch_size,
                          epochs=epochs, verbose=2,
                          validation_data=(val_x, val_y),
                          class_weight=class_weights,
                          callbacks=[es])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 200)               123600
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense (Dense)               (None, 70)                14070
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 20)                1420
#
#  dense_2 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 139111 (543.40 KB)
# Trainable params: 139111 (543.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 175/175 - 23s - loss: 1.9208 - accuracy: 0.4061 - val_loss: 1.2165 - val_accuracy: 0.5821 - 23s/epoch - 133ms/step
# Epoch 2/40
# 175/175 - 23s - loss: 1.9068 - accuracy: 0.4680 - val_loss: 1.1977 - val_accuracy: 0.6943 - 23s/epoch - 132ms/step
# Epoch 3/40
# 175/175 - 23s - loss: 1.8889 - accuracy: 0.5638 - val_loss: 1.1923 - val_accuracy: 0.4671 - 23s/epoch - 130ms/step
# Epoch 4/40
# 175/175 - 28s - loss: 1.8754 - accuracy: 0.4954 - val_loss: 1.1743 - val_accuracy: 0.5571 - 28s/epoch - 159ms/step
# Epoch 5/40
# 175/175 - 23s - loss: 1.8613 - accuracy: 0.5093 - val_loss: 1.1562 - val_accuracy: 0.6486 - 23s/epoch - 130ms/step
# Epoch 6/40
# 175/175 - 30s - loss: 1.8488 - accuracy: 0.6050 - val_loss: 1.1526 - val_accuracy: 0.4679 - 30s/epoch - 173ms/step
# Epoch 7/40
# 175/175 - 26s - loss: 1.8339 - accuracy: 0.5121 - val_loss: 1.1358 - val_accuracy: 0.5364 - 26s/epoch - 149ms/step
# Epoch 8/40
# 175/175 - 26s - loss: 1.8199 - accuracy: 0.5284 - val_loss: 1.1202 - val_accuracy: 0.5936 - 26s/epoch - 149ms/step
# Epoch 9/40
# 175/175 - 21s - loss: 1.8071 - accuracy: 0.5602 - val_loss: 1.1106 - val_accuracy: 0.5436 - 21s/epoch - 122ms/step
# Epoch 10/40
# 175/175 - 21s - loss: 1.7942 - accuracy: 0.5523 - val_loss: 1.1031 - val_accuracy: 0.5007 - 21s/epoch - 120ms/step
# Epoch 11/40
# 175/175 - 22s - loss: 1.7829 - accuracy: 0.5371 - val_loss: 1.0909 - val_accuracy: 0.5114 - 22s/epoch - 125ms/step
# Epoch 12/40
# 175/175 - 25s - loss: 1.7718 - accuracy: 0.5618 - val_loss: 1.0784 - val_accuracy: 0.5229 - 25s/epoch - 143ms/step
# Epoch 13/40
# 175/175 - 21s - loss: 1.7581 - accuracy: 0.5430 - val_loss: 1.0636 - val_accuracy: 0.5471 - 21s/epoch - 121ms/step
# Epoch 14/40
# 175/175 - 20s - loss: 1.7460 - accuracy: 0.5636 - val_loss: 1.0569 - val_accuracy: 0.5207 - 20s/epoch - 117ms/step
# Epoch 15/40
# 175/175 - 20s - loss: 1.7345 - accuracy: 0.5327 - val_loss: 1.0426 - val_accuracy: 0.5514 - 20s/epoch - 114ms/step
# Epoch 16/40
# 175/175 - 20s - loss: 1.7215 - accuracy: 0.5796 - val_loss: 1.0376 - val_accuracy: 0.5121 - 20s/epoch - 116ms/step
# Epoch 17/40
# 175/175 - 20s - loss: 1.7113 - accuracy: 0.5766 - val_loss: 1.0281 - val_accuracy: 0.5086 - 20s/epoch - 116ms/step
# Epoch 18/40
# 175/175 - 20s - loss: 1.6957 - accuracy: 0.5739 - val_loss: 1.0120 - val_accuracy: 0.5443 - 20s/epoch - 114ms/step
# Epoch 19/40
# 175/175 - 20s - loss: 1.6848 - accuracy: 0.5738 - val_loss: 0.9985 - val_accuracy: 0.5757 - 20s/epoch - 116ms/step
# Epoch 20/40
# 175/175 - 21s - loss: 1.6692 - accuracy: 0.6070 - val_loss: 0.9917 - val_accuracy: 0.5536 - 21s/epoch - 121ms/step
# Epoch 21/40
# 175/175 - 21s - loss: 1.6425 - accuracy: 0.6091 - val_loss: 0.9479 - val_accuracy: 0.7064 - 21s/epoch - 122ms/step
# Epoch 22/40
# 175/175 - 20s - loss: 1.1963 - accuracy: 0.8318 - val_loss: 0.4828 - val_accuracy: 0.9979 - 20s/epoch - 115ms/step
# Epoch 23/40
# 175/175 - 20s - loss: 0.4312 - accuracy: 0.9987 - val_loss: 0.3337 - val_accuracy: 1.0000 - 20s/epoch - 116ms/step
# Epoch 24/40
# 175/175 - 20s - loss: 0.3276 - accuracy: 0.9998 - val_loss: 0.3004 - val_accuracy: 1.0000 - 20s/epoch - 115ms/step
# Epoch 25/40
# 175/175 - 20s - loss: 0.3045 - accuracy: 0.9995 - val_loss: 0.2871 - val_accuracy: 1.0000 - 20s/epoch - 116ms/step
# Epoch 26/40
# 175/175 - 20s - loss: 0.2887 - accuracy: 0.9998 - val_loss: 0.2765 - val_accuracy: 1.0000 - 20s/epoch - 115ms/step
# Epoch 27/40
# 175/175 - 20s - loss: 0.2761 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 1.0000 - 20s/epoch - 113ms/step
# Epoch 28/40
# 175/175 - 20s - loss: 0.2670 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 1.0000 - 20s/epoch - 113ms/step
# Epoch 29/40
# 175/175 - 22s - loss: 0.2592 - accuracy: 0.9998 - val_loss: 0.2525 - val_accuracy: 1.0000 - 22s/epoch - 126ms/step
# Epoch 30/40
# 175/175 - 24s - loss: 0.2514 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 1.0000 - 24s/epoch - 136ms/step
# Epoch 31/40
# 175/175 - 19s - loss: 0.2443 - accuracy: 1.0000 - val_loss: 0.2387 - val_accuracy: 1.0000 - 19s/epoch - 110ms/step
# Epoch 32/40
# 175/175 - 20s - loss: 0.2374 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 1.0000 - 20s/epoch - 115ms/step
# Epoch 33/40
# 175/175 - 19s - loss: 0.2313 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 1.0000 - 19s/epoch - 110ms/step
# Epoch 34/40
# 175/175 - 20s - loss: 0.2247 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 1.0000 - 20s/epoch - 117ms/step
# Epoch 35/40
# 175/175 - 27s - loss: 0.2190 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 1.0000 - 27s/epoch - 152ms/step
# Epoch 36/40
# 175/175 - 21s - loss: 0.2127 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 1.0000 - 21s/epoch - 121ms/step
# Epoch 37/40
# 175/175 - 23s - loss: 0.2068 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 1.0000 - 23s/epoch - 132ms/step
# Epoch 38/40
# 175/175 - 24s - loss: 0.2010 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 1.0000 - 24s/epoch - 137ms/step
# Epoch 39/40
# 175/175 - 17s - loss: 0.1960 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 1.0000 - 17s/epoch - 97ms/step
# Epoch 40/40
# 175/175 - 17s - loss: 0.1906 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 1.0000 - 17s/epoch - 95ms/step

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

print(roc_auc_score(test_y, model.predict(test_x)))
print(accuracy_score(test_y, np.round(model.predict(test_x))))
# Out:
# 94/94 [==============================] - 3s 29ms/step
# 1.0
# 94/94 [==============================] - 2s 26ms/step
# 1.0

# %%
test_y[20:30]
# Out:
# array([0., 0., 1., 0., 0., 0., 1., 0., 1., 1.])

# %% [markdown]
# ## SHAP interpretation

# %%
num_background = 50
num_test = 28
background_data, test_data = train_x[:num_background], test_x[num_test:num_test + 2]

# %% [markdown]
# ## 4- Ruptures Dynamic WindowSHAP

# %%
from window_shap import *

class RupturesDynamicWindowSHAP(SHAP):
    """RupturesDynamicWindowSHAP class"""

    def __init__(self, model, delta, n_w, B_ts, test_ts, B_mask=None, B_dem=None,
                 test_mask=None, test_dem=None, model_type='lstm', rpt_search="Pelt", rpt_pen=3, rpt_model='rbf', n_bkps=3):

        # Ruptures setting
        self.rpt_search = rpt_search
        self.rpt_pen = rpt_pen
        self.rpt_model = rpt_model
        self.n_bkps = n_bkps
        
        self.delta = delta
        self.n_w = n_w
        num_window = [1] * B_ts.shape[2]
        super().__init__(model, B_ts, test_ts, num_window, B_mask,
                         B_dem, test_mask, test_dem, model_type)

        # Splitting points
        if self.rpt_search == "Dynp":
            self.split_points = [rpt.Dynp(model=self.rpt_model, min_size=3, jump=5).fit(B_ts[0]).predict(n_bkps=self.n_bkps)] * self.num_ts_ftr
        elif self.rpt_search == "Pelt":
            self.split_points = [rpt.Pelt(model=self.rpt_model).fit(B_ts[0]).predict(pen=self.rpt_pen)] * self.num_ts_ftr 
        elif self.rpt_search == "KernelCPD":
            self.split_points = [rpt.KernelCPD(kernel="linear", min_size=2).fit(B_ts[0]).predict(n_bkps=self.n_bkps)] * self.num_ts_ftr
        elif self.rpt_search == "Binseg":
            self.split_points = [rpt.Binseg(model=self.rpt_model).fit(B_ts[0]).predict(n_bkps=self.n_bkps)] * self.num_ts_ftr
        elif self.rpt_search == "BottomUp":
            self.split_points = [rpt.BottomUp(model=self.rpt_model).fit(B_ts[0]).predict(n_bkps=self.n_bkps)] * self.num_ts_ftr
        elif self.rpt_search == "Window":
            self.split_points = [rpt.Window(model=self.rpt_model, width=40).fit(B_ts[0]).predict(n_bkps=self.n_bkps)] * self.num_ts_ftr
        
        print("Split points")
        print(self.split_points)

        self.prepare_data(dynamic=True)

    def get_ts_x_(self, x):
        return np.zeros((x.shape[0], self.num_ts_step, self.num_ts_ftr))

    def get_ts_x(self, x):
        ts_x = x[:, self.num_dem_ftr:].copy()

        temp_ts_x = np.zeros((ts_x.shape[0], max(self.num_window), self.num_ts_ftr), dtype=int)
        for i in range(self.num_ts_ftr):
            temp_ts_x[:, :self.num_window[i], i] = ts_x[:, sum(self.num_window[:i]):sum(
                self.num_window[:i + 1])]
        return temp_ts_x

    def get_tstep(self, x):
        return np.ones((x.shape[0], self.num_ts_step, 1)) * \
            np.reshape(np.arange(0, self.num_ts_step), (1, self.num_ts_step, 1))

    def creating_data(self, x, ts_x, ts_x_, mask_x_, start_ind=0):
        for i in range(x.shape[0]):
            # creating time series data
            for j in range(self.num_ts_ftr):
                # Finding the corresponding time interval
                wind_t = np.searchsorted(self.split_points[j], np.arange(
                    self.num_ts_step))  ## Specific to Binary Time Window
                for t in range(self.num_ts_step):
                    ind = ts_x[i, wind_t[t], j]
                    ts_x_[i, t, j] = self.all_ts[ind, t, j]
                    mask_x_[i, t, j] = None if self.all_mask is None else self.all_mask[ind, t, j]
        return ts_x_, mask_x_

    def shap_values(self, num_output=1, nsamples_in_loop='auto', nsamples_final='auto'):
        """shap value for dynamic window."""

        flag = 1
        while flag:
            flag = 0

            # Updating the number of time windows for each time series feature
            self.num_window = [len(self.split_points[i]) for i in range(self.num_ts_ftr)]

            # Updating converted data for SHAP
            self.background_data = data_prepare(self.B_ts,
                                                self.num_dem_ftr,
                                                self.num_window,
                                                self.num_ts_ftr,
                                                dynamic=True)
            self.test_data = data_prepare(self.test_ts,
                                          self.num_dem_ftr,
                                          self.num_window,
                                          self.num_ts_ftr,
                                          len(self.B_ts),
                                          dynamic=True)

            # Running SHAP
            if nsamples_in_loop == 'auto':
                nsamples = 2 * sum(self.num_window)
            else:
                nsamples = nsamples_in_loop

            self.explainer = shap.KernelExplainer(self.wrapper_predict, self.background_data)
            shap_values = self.explainer.shap_values(self.test_data, nsamples=nsamples)
            shap_values = np.array(shap_values)
            dem_phi = shap_values[0, :, :self.num_dem_ftr]  # Extracting dem SHAP values
            ts_shap_values = shap_values[:, :, self.num_dem_ftr:]  # Extracting ts SHAP values

            # Checking the maximum number of windows condition
            if max(self.num_window) >= self.n_w: break

            for i in range(self.num_ts_ftr):
                S = set(self.split_points[i])
                for j in range(self.num_window[i]):
                    if abs(ts_shap_values[0, 0, sum(self.num_window[:i]) + j]) > self.delta:
                        S.add(int(self.split_points[i][j] / 2) if j == 0 else int(
                            (self.split_points[i][j - 1] + self.split_points[i][j]) / 2))
                if set(S) != set(self.split_points[i]):
                    flag += 1
                    self.split_points[i] = list(S)
                    self.split_points[i].sort()

        # Running SHAP with large number of samples for the final evaluation of Shapely values
        self.explainer = shap.KernelExplainer(self.wrapper_predict, self.background_data)
        shap_values = self.explainer.shap_values(self.test_data, nsamples=nsamples_final)
        shap_values = np.array(shap_values)
        dem_phi = shap_values[0, :, :self.num_dem_ftr]  # Extracting dem SHAP values
        ts_shap_values = shap_values[:, :, self.num_dem_ftr:]  # Extracting ts SHAP values

        # Assigning Shap values to each single time step
        ts_phi = np.zeros((len(self.test_ts), self.num_ts_step, self.num_ts_ftr))
        for i in range(self.num_ts_ftr):
            for j in range(self.num_window[i]):
                # This part of the code is written in a way that each splitting point belongs to the time window that starts from that point
                # For the last time window, both splitting points at the end and start of the time window belong to it
                start_ind = 0 if j == 0 else self.split_points[i][j - 1]
                end_ind = self.split_points[i][j] + int((j + 1) / self.num_window[i])
                ts_phi[0, start_ind:end_ind, i] = ts_shap_values[0, :,
                                                  sum(self.num_window[:i]) + j] / (
                                                          end_ind - start_ind)
        self.dem_phi = dem_phi
        self.ts_phi = ts_phi

        return ts_phi if self.num_dem_ftr == 0 else (dem_phi, ts_phi)

# %%
tic = timeit.default_timer()
ts_phi_4 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    rtw = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_4[i, :, :] = rtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# Split points
# [[80, 100, 120], [80, 100, 120], [80, 100, 120], [80, 100, 120]]
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 38/38 [==============================] - 2s 42ms/step
# 2/2 [==============================] - 0s 42ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 100ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 8
#       5     n_w = 8
#       6     rtw = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
#       7                             model_type='lstm')
# ----> 8     ts_phi_4[i, :, :] = rtw.shap_values()
#       9 print('Total time: ' + str(timeit.default_timer() - tic))
#
# Cell In[74], line 99, in RupturesDynamicWindowSHAP.shap_values(self, num_output, nsamples_in_loop, nsamples_final)
#      96     nsamples = nsamples_in_loop
#      98 self.explainer = shap.KernelExplainer(self.wrapper_predict, self.background_data)
# ---> 99 shap_values = self.explainer.shap_values(self.test_data, nsamples=nsamples)
#     100 shap_values = np.array(shap_values)
#     101 dem_phi = shap_values[0, :, :self.num_dem_ftr]  # Extracting dem SHAP values
#
# File ~/Desktop/phd/xai/WindowSHAP/venv/lib/python3.9/site-packages/shap/explainers/_kernel.py:242, in KernelExplainer.shap_values(self, X, **kwargs)
#     240 if self.keep_index:
#     241     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 242 explanations.append(self.explain(data, **kwargs))
#     243 if kwargs.get("gc_collect", False):
#     244     gc.collect()
#
# File ~/Desktop/phd/xai/WindowSHAP/venv/lib/python3.9/site-packages/shap/explainers/_kernel.py:436, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     433     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     435 # execute the model on the synthetic samples we have created
# --> 436 self.run()
#     438 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     439 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~/Desktop/phd/xai/WindowSHAP/venv/lib/python3.9/site-packages/shap/explainers/_kernel.py:575, in KernelExplainer.run(self)
#     573     if self.keep_index_ordered:
#     574         data = data.sort_index()
# --> 575 modelOut = self.model.f(data)
#     576 if isinstance(modelOut, (pd.DataFrame, pd.Series)):
#     577     modelOut = modelOut.values
#
# File ~/Desktop/phd/xai/WindowSHAP/window_shap.py:111, in SHAP.wrapper_predict(self, x, start_ind)
#     109 def wrapper_predict(self, x, start_ind=0):
#     110     """predicts for delivered model."""
# --> 111     ts_x_, dem_x_, mask_x_, tstep = self.get_model_inputs(x, start_ind)
#     113     model_dict = {'lstm_dem': [ts_x_, dem_x_],
#     114                   'grud': [ts_x_, mask_x_, tstep],
#     115                   'lstm': ts_x_}
#     116     return self.model.predict(model_dict[self.model_type])
#
# File ~/Desktop/phd/xai/WindowSHAP/window_shap.py:106, in SHAP.get_model_inputs(self, x, start_ind)
#     104 mask_x_ = np.zeros_like(ts_x_)
#     105 dem_x_ = np.zeros_like(dem_x, dtype=float)
# --> 106 ts_x_, mask_x_ = self.creating_data(x, ts_x, ts_x_, mask_x_, start_ind)
#     107 return ts_x_, dem_x_, mask_x_, tstep
#
# Cell In[74], line 61, in RupturesDynamicWindowSHAP.creating_data(self, x, ts_x, ts_x_, mask_x_, start_ind)
#      57 for i in range(x.shape[0]):
#      58     # creating time series data
#      59     for j in range(self.num_ts_ftr):
#      60         # Finding the corresponding time interval
# ---> 61         wind_t = np.searchsorted(self.split_points[j], np.arange(
#      62             self.num_ts_step))  ## Specific to Binary Time Window
#      63         for t in range(self.num_ts_step):
#      64             ind = ts_x[i, wind_t[t], j]
#
# File ~/Desktop/phd/xai/WindowSHAP/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1400, in searchsorted(a, v, side, sorter)
#    1332 @array_function_dispatch(_searchsorted_dispatcher)
#    1333 def searchsorted(a, v, side='left', sorter=None):
#    1334     """
#    1335     Find indices where elements should be inserted to maintain order.
#    1336
#    (...)
#    1398
#    1399     """
# -> 1400     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File ~/Desktop/phd/xai/WindowSHAP/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:53, in _wrapfunc(obj, method, *args, **kwds)
#      49         result = wrap(result)
#      50     return result
# ---> 53 def _wrapfunc(obj, method, *args, **kwds):
#      54     bound = getattr(obj, method, None)
#      55     if bound is None:
#
# KeyboardInterrupt:

# %%
var = 0
phi_index = 0
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_4[phi_index, :, var], var_name='Variable', plot_type='bar')

# %%
tic = timeit.default_timer()
ts_phi_4 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    rtw = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_4[i, :, :] = rtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 120
# 4
# Split points
# [[80, 100, 120], [120], [120], [75, 95, 120], [85, 105, 120], [45, 65, 120], [80, 95, 120], [40, 60, 120], [20, 45, 120], [20, 120], [25, 120], [25, 120], [85, 105, 120], [40, 60, 120], [70, 90, 120], [120], [30, 120], [65, 85, 120], [75, 95, 120], [120], [120], [120], [120], [90, 110, 120], [25, 45, 120], [10, 25, 120], [120], [85, 105, 115, 120], [40, 60, 120], [120], [120], [120], [85, 105, 120], [120], [120], [60, 80, 120], [80, 105, 120], [75, 100, 120], [30, 55, 120], [120], [30, 50, 120], [35, 120], [40, 60, 120], [50, 70, 120], [85, 105, 120], [80, 100, 120], [120], [15, 35, 120], [65, 85, 120], [50, 70, 120]]
# Num windows
# [3, 1, 1, 3]
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 59ms/step
# 25/25 [==============================] - 1s 33ms/step
# Num windows
# [4, 1, 1, 3]
# 2/2 [==============================] - 0s 39ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 29/29 [==============================] - 1s 38ms/step
# Num windows
# [5, 1, 1, 3]
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 73ms/step
# 32/32 [==============================] - 1s 33ms/step
# Num windows
# [6, 1, 1, 3]
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 54ms/step
# 35/35 [==============================] - 1s 33ms/step
# Num windows
# [7, 1, 1, 4]
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 41/41 [==============================] - 1s 33ms/step
# Num windows
# [8, 1, 1, 4]
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 44/44 [==============================] - 2s 36ms/step
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 3244/3244 [==============================] - 105s 32ms/step
# 120
# 4
# Split points
# [[80, 100, 120], [120], [120], [75, 95, 120], [85, 105, 120], [45, 65, 120], [80, 95, 120], [40, 60, 120], [20, 45, 120], [20, 120], [25, 120], [25, 120], [85, 105, 120], [40, 60, 120], [70, 90, 120], [120], [30, 120], [65, 85, 120], [75, 95, 120], [120], [120], [120], [120], [90, 110, 120], [25, 45, 120], [10, 25, 120], [120], [85, 105, 115, 120], [40, 60, 120], [120], [120], [120], [85, 105, 120], [120], [120], [60, 80, 120], [80, 105, 120], [75, 100, 120], [30, 55, 120], [120], [30, 50, 120], [35, 120], [40, 60, 120], [50, 70, 120], [85, 105, 120], [80, 100, 120], [120], [15, 35, 120], [65, 85, 120], [50, 70, 120]]
# Num windows
# [3, 1, 1, 3]
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 55ms/step
# 25/25 [==============================] - 1s 43ms/step
# Num windows
# [4, 1, 1, 3]
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 45ms/step
# 29/29 [==============================] - 1s 36ms/step
# Num windows
# [5, 1, 1, 3]
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 66ms/step
# 32/32 [==============================] - 1s 37ms/step
# Num windows
# [6, 1, 1, 3]
# 2/2 [==============================] - 0s 37ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 54ms/step
# 35/35 [==============================] - 1s 32ms/step
# Num windows
# [8, 1, 1, 3]
# 2/2 [==============================] - 0s 38ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 56ms/step
# 41/41 [==============================] - 2s 37ms/step
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 3241/3241 [==============================] - 110s 34ms/step
# Total time: 327.1879989270001

# %%
var = 0
phi_index = 0
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_4[phi_index, :, var], var_name='Variable', plot_type='bar')

# %%
import matplotlib.pyplot as plt
import ruptures as rpt

# generate signal
n_samples, dim, sigma = 1000, 4, 4
n_bkps = 4  # number of breakpoints
signal, bkps = rpt.pw_constant(n_samples, dim, n_bkps, noise_std=sigma)

# detection
algo = rpt.Pelt(model="rbf").fit(signal)
result = algo.predict(pen=3)

print(signal.shape)
print(result)
# display
rpt.display(signal, bkps, result)
plt.show()
# Out:
# (1000, 4)
# [205, 415, 610, 825, 1000]

# %%
print(signal.shape)
# Out:
# (1000, 4)

# %%
print(background_data[1].shape)
# Out:
# (120, 4)

# %%
print(background_data[0].shape)
print(background_data.shape[0])
# print(test_data[i:i + 1].shape)
#
# Out:
# (120, 4)
# 50

# %%
data = background_data[0]
algo = rpt.Pelt(model="rbf").fit(data)
result = algo.predict(pen=3)

print(result)
rpt.display(data, [0], result)
plt.show()
# Out:
# [80, 100, 120]

# %%
for i in range(background_data.shape[0]):
    data = background_data[i]
    algo = rpt.Pelt(model="rbf").fit(data)
    result = algo.predict(pen=2)
    
    # print(result)
    # rpt.display(data, [0], result)
    # plt.show()

# %%
tic = timeit.default_timer()
ts_phi_4 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    rtw = RupturesDynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_4[i, :, :] = rtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 120
# 4
# Split points
# [[119], [119], [119], [119]]
# Num windows
# [1, 1, 1, 1]
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 46ms/step
# 13/13 [==============================] - 0s 32ms/step
# Num windows
# [2, 1, 1, 1]
# 2/2 [==============================] - 0s 38ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 52ms/step
# 16/16 [==============================] - 1s 38ms/step
# Num windows
# [3, 1, 1, 1]
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 65ms/step
# 19/19 [==============================] - 1s 36ms/step
# Num windows
# [4, 1, 1, 1]
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 22/22 [==============================] - 1s 47ms/step
# Num windows
# [5, 1, 1, 1]
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 55ms/step
# 25/25 [==============================] - 1s 35ms/step
# Num windows
# [7, 1, 1, 1]
# 2/2 [==============================] - 0s 39ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 32/32 [==============================] - 1s 32ms/step
# Num windows
# [9, 1, 1, 1]
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 60ms/step
# 38/38 [==============================] - 1s 34ms/step
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 3238/3238 [==============================] - 110s 34ms/step
# 120
# 4
# Split points
# [[119], [119], [119], [119]]
# Num windows
# [1, 1, 1, 1]
# 2/2 [==============================] - 0s 34ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 42ms/step
# 13/13 [==============================] - 0s 34ms/step
# Num windows
# [2, 1, 1, 1]
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 64ms/step
# 16/16 [==============================] - 1s 32ms/step
# Num windows
# [3, 1, 1, 1]
# 2/2 [==============================] - 0s 41ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 62ms/step
# 19/19 [==============================] - 1s 33ms/step
# Num windows
# [4, 1, 1, 1]
# 2/2 [==============================] - 0s 29ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 22/22 [==============================] - 1s 37ms/step
# Num windows
# [5, 1, 1, 1]
# 2/2 [==============================] - 0s 44ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 25/25 [==============================] - 1s 34ms/step
# Num windows
# [7, 1, 1, 1]
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 44ms/step
# 32/32 [==============================] - 1s 38ms/step
# Num windows
# [8, 1, 1, 1]
# 2/2 [==============================] - 0s 98ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 52ms/step
# 35/35 [==============================] - 1s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 54ms/step
# 3197/3197 [==============================] - 143s 45ms/step
# Total time: 375.50277895499994

# %%
print(ts_phi_4.shape)
# Out:
# (2, 120, 4)

# %%
var = 0
phi_index = 0
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_4[phi_index, :, var], var_name='Variable', plot_type='bar')

# %% [markdown]
# ## 1- Stationary WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_1 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    gtw = StationaryWindowSHAP(model, window_len, B_ts=background_data, test_ts=test_data[i:i + 1], model_type='lstm')
    ts_phi_1[i, :, :] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 50ms/step
# 3275/3275 [==============================] - 76s 23ms/step
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 3275/3275 [==============================] - 75s 23ms/step
# Total time: 445.0816045229999

# %% [markdown]
# ## 2- Sliding WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_2 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    window_len = 20
    stride = 10
    gtw = SlidingWindowSHAP(model, stride, window_len, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_2[i, :, :] = gtw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 44ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 33ms/step
# 63/63 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 30ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 34ms/step
# 63/63 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 20ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 63/63 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 21ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 19ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 63/63 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 31ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 22ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 49ms/step
# 63/63 [==============================] - 1s 22ms/step
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 36ms/step
# 63/63 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 63/63 [==============================] - 1s 22ms/step
# Total time: 71.38203135100002

# %% [markdown]
# ## 3- Dynamic WindowSHAP

# %%
tic = timeit.default_timer()
ts_phi_3 = np.zeros((len(test_data), test_data.shape[1], test_data.shape[2]))
for i in range(len(test_data)):
    delta = 0.3
    n_w = 8
    btw = DynamicWindowSHAP(model, delta, n_w, background_data, test_data[i:i + 1],
                            model_type='lstm')
    ts_phi_3[i, :, :] = btw.shap_values()
print('Total time: ' + str(timeit.default_timer() - tic))
# Out:
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 37ms/step
# 13/13 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 16/16 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 19/19 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 22/22 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 32ms/step
# 25/25 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 29/29 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 35ms/step
# 35/35 [==============================] - 1s 23ms/step
# 2/2 [==============================] - 0s 27ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 41ms/step
# 3197/3197 [==============================] - 87s 27ms/step
# 2/2 [==============================] - 0s 33ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 43ms/step
# 13/13 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 39ms/step
# 16/16 [==============================] - 1s 41ms/step
# 2/2 [==============================] - 0s 35ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 47ms/step
# 19/19 [==============================] - 1s 44ms/step
# 2/2 [==============================] - 0s 28ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 126ms/step
# 22/22 [==============================] - 1s 35ms/step
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 40ms/step
# 25/25 [==============================] - 1s 33ms/step
# 2/2 [==============================] - 0s 37ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 38ms/step
# 32/32 [==============================] - 1s 35ms/step
# 2/2 [==============================] - 0s 31ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 48ms/step
# 35/35 [==============================] - 1s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 64ms/step
# 3197/3197 [==============================] - 113s 35ms/step
# Total time: 365.3261911929999

# %%
# from utils import heat_map

var = 0
phi_index = 0
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_1[phi_index, :, var], var_name='Observed', plot_type='bar')
heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_2[phi_index, :, var], var_name='Observed', plot_type='bar')

heat_map(start=0, stop=120, x=test_x[num_test + phi_index, :, var],
         shap_values=ts_phi_3[phi_index, :, var], var_name='Variable', plot_type='bar')
